# %% [markdown]
# #### 🐚 What is Seaborn?
# ✅ Seaborn is a Python library for data visualization.
# ✅ It’s built on top of Matplotlib, but is prettier and easier to use.
# ✅ It helps you create beautiful, clean, and complex plots with very little code.
#
# Think of it like:
#
# Matplotlib = raw camera
#
# Seaborn = Instagram filter 💎

# %%
import seaborn as sns

# %%
### basic ploting with seaborn

tips=sns.load_dataset("tips")
tips.head(6)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4

# %%
tips.groupby("total_bill")["tip"].sum()
# Out:
# total_bill
# 3.07      1.00
# 5.75      1.00
# 7.25      6.15
# 7.51      2.00
# 7.56      1.44
#          ...
# 45.35     3.50
# 48.17     5.00
# 48.27     6.73
# 48.33     9.00
# 50.81    10.00
# Name: tip, Length: 229, dtype: float64

# %%
### create scatter plot
import matplotlib.pyplot as plt

sns.scatterplot(x="total_bill",y="tip",data=tips)
plt.title(" scatter plot of Total bill and tip")
# Out:
# Text(0.5, 1.0, ' scatter plot of Total bill and tip')

# %%
### line plot
sns.lineplot(x="size",y="total_bill",data=tips)
plt.title(" scatter plot of Total bill by size")
# Out:
# Text(0.5, 1.0, ' scatter plot of Total bill by size')

# %%
### cateegorical plots
sns.barplot(x="day",y="total_bill",data=tips)
plt.title(" scatter plot of Total bill by day")
plt.show()

# %%
### box plot

sns.boxplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
## voilin plot
sns.violinplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
### histogram
sns.histplot(tips["total_bill"],bins=10,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
### kde plot
sns.kdeplot(tips["total_bill"],shade=True)
# Out:
# C:\Users\susov\AppData\Local\Temp\ipykernel_9432\1073254732.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips["total_bill"],shade=True)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
## pairplot
sns.pairplot(tips)

# %%
### heatmap
corr=tips[["total_bill","tip","size"]].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
import pandas as pd

sales_df=pd.read_csv("sales_data.csv")
sales_df.head(3)
# Out:
#    Transaction ID        Date Product Category      Product Name  Units Sold  \
# 0           10001  2024-01-01      Electronics     iPhone 14 Pro           2
# 1           10002  2024-01-02  Home Appliances  Dyson V11 Vacuum           1
# 2           10003  2024-01-03         Clothing  Levi's 501 Jeans           3
#
#    Unit Price  Total Revenue         Region Payment Method
# 0      999.99        1999.98  North America    Credit Card
# 1      499.99         499.99         Europe         PayPal
# 2       69.99         209.97           Asia     Debit Card

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="Product Category",y="Total Revenue",data=sales_df,estimator=sum)
plt.title("top sales")
# Out:
# Text(0.5, 1.0, 'top sales')

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="Region",y="Total Revenue",data=sales_df,estimator=sum)
plt.title("top sales")
# Out:
# Text(0.5, 1.0, 'top sales')
