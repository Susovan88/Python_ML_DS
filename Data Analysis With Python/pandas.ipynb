# %% [markdown]
# ###  Pandas = Python Data Analysis Library
#
# It is a powerful tool for working with structured data (like tables in Excel or SQL).
# Built on top of NumPy, but adds tools for handling rows & columns easily.
#
# You’ll use Pandas for:
# ✅ Data cleaning
# ✅ Data analysis
# ✅ Data manipulation (filter, group, merge, etc.)
# ✅ Reading/writing files (CSV, Excel, SQL, etc.)

# %% [markdown]
# | **Method**                       | **What It Does**                                          |
# | -------------------------------- | --------------------------------------------------------- |
# | `pd.DataFrame(data)`             | Create a DataFrame from data (list, dict, array, etc.).   |
# | `df.set_index('column')`         | Set a column as the row index.                            |
# | `df.loc[row, col]`               | Access rows and columns by labels.                        |
# | `df.iloc[row, col]`              | Access rows and columns by index positions.               |
# | `df['new_column'] = ...`         | Add a new column to the DataFrame.                        |
# | `df.sum(axis=0)`                 | Compute column-wise sum (default).                        |
# | `df.sum(axis=1)`                 | Compute row-wise sum.                                     |
# | `df.fillna(value)`               | Replace all NaN (missing values) with a specified value.  |
# | `df.fillna(df.mean())`           | Replace NaN with the column mean.                         |
# | `df.dropna()`                    | Drop rows with any NaN values.                            |
# | `df.groupby('col')`              | Group data by unique values in a column.                  |
# | `df.groupby('col')['val'].sum()` | Group by column and compute sum of another column.        |
# | `df.groupby(['A', 'B'])`         | Perform grouping on multiple columns (multi-level group). |
# | `pd.merge(df1, df2, on='col')`   | Merge two DataFrames using a common column.               |
# | `pd.concat([df1, df2], axis=0)`  | Concatenate DataFrames vertically (row-wise).             |
# | `pd.concat([df1, df2], axis=1)`  | Concatenate DataFrames horizontally (column-wise).        |
# | `pd.date_range(start, end)`      | Create a date range (useful for datetime index).          |
# | `df.resample('M').mean()`        | Resample data (e.g., monthly) and compute mean.           |
# | `df.rolling(window=7).mean()`    | Compute a rolling (moving) average over a window size.    |
# | `pd.MultiIndex.from_tuples()`    | Create a multi-level (hierarchical) index.                |
# | `df.loc[('A', 'X')]`             | Access data from a MultiIndex DataFrame.                  |
# | `df.sum(level='Category')`       | Sum over one level in a MultiIndex DataFrame.             |
# | `pd.pivot_table()`               | Create pivot tables for summarizing data.                 |
# | `df.apply(func)`                 | Apply a function row-wise or column-wise.                 |
# | `df.applymap(func)`              | Apply a function element-wise on all DataFrame values.    |
# | `series.str.upper()`             | Convert all strings in a Series to uppercase.             |
# | `series.str[:3]`                 | Slice the first 3 characters of each string in a Series.  |

# %%
import pandas as pd

# %% [markdown]
# ###  A Series is:
# ✅ A one-dimensional labeled array in Pandas.
# ✅ It holds data values and an index (labels for those values).
# ✅ Think of it as a single column of an Excel sheet.

# %%
lst=[1,2,4,6,8]

series=pd.Series(lst)
print(series)
print(type(series))
# Out:
# 0    1
# 1    2
# 2    4
# 3    6
# 4    8
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
## series from dictionary
data={'a':123,'b':980,'c':567}

series_dict=pd.Series(data)
print(series_dict)
# Out:
# a    123
# b    980
# c    567
# dtype: int64

# %%
data=[123,456,789,975,421,909]
idx=['a','b','c','d','e','f']

series_data=pd.Series(data,index=idx)
print(series_data)
# Out:
# a    123
# b    456
# c    789
# d    975
# e    421
# f    909
# dtype: int64

# %% [markdown]
# ####  What is a DataFrame?
# A DataFrame is:
# ✅ A 2D table in Pandas (rows and columns)
# ✅ Like an Excel sheet or a SQL table
# ✅ Built using Series (each column is a Series)
#
# It’s the most powerful structure in Pandas for data analysis.

# %%
## create dataframe from dictionary of lists
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Paris', 'London']
}

df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30     Paris
# 2  Charlie   35    London
# <class 'pandas.core.frame.DataFrame'>

# %%
## create dataframe from list dictionarys
data=[
    {'name':"susovan","age":23,"city":"kolkata"},
    {'name':"pupai","age":23,"city":"kolkata"},
    {'name':"sovan","age":21,"city":"Howrah"},
    {'name':"Mimi","age":20,"city":"kolkata"},
    {'name':"Taniya","age":23,"city":"kolkata"},
    {'name':"Ram","age":24,"city":"Huggly"},
]

df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#       name  age     city
# 0  susovan   23  kolkata
# 1    pupai   23  kolkata
# 2    sovan   21   Howrah
# 3     Mimi   20  kolkata
# 4   Taniya   23  kolkata
# 5      Ram   24   Huggly
# <class 'pandas.core.frame.DataFrame'>

# %%
## access cols
print(df["name"])
# Out:
# 0    susovan
# 1      pupai
# 2      sovan
# 3       Mimi
# 4     Taniya
# 5        Ram
# Name: name, dtype: object

# %%
print(df[["name","age"]])
print(df[["age","city"]])
# Out:
#       name  age
# 0  susovan   23
# 1    pupai   23
# 2    sovan   21
# 3     Mimi   20
# 4   Taniya   23
# 5      Ram   24
#    age     city
# 0   23  kolkata
# 1   23  kolkata
# 2   21   Howrah
# 3   20  kolkata
# 4   23  kolkata
# 5   24   Huggly

# %% [markdown]
# ###   df.iloc[] → Access by Position
# ✅ Access rows or cells by integer position (row & column numbers).
#
# ###  df.loc[] → Access by Labels
# ✅ Access rows or cells by row labels (index) and column names.

# %%
### access row
data=[
    {'name':"susovan","age":23,"city":"Delhi"},
    {'name':"pupai","age":23,"city":"Mumbai"},
    {'name':"sovan","age":21,"city":"Howrah"},
    {'name':"Mimi","age":20,"city":"kolkata"},
    {'name':"Taniya","age":23,"city":"Goa"},
    {'name':"Ram","age":24,"city":"Huggly"},
]
idx=['a','b','c','d','e','f']
df=pd.DataFrame(data,index=idx)
print(df)
print(df.loc['b'])
print(df.loc['c',"city"])
# Out:
#       name  age     city
# a  susovan   23    Delhi
# b    pupai   23   Mumbai
# c    sovan   21   Howrah
# d     Mimi   20  kolkata
# e   Taniya   23      Goa
# f      Ram   24   Huggly
# name     pupai
# age         23
# city    Mumbai
# Name: b, dtype: object
# Howrah

# %%
print(df.loc['c':'f',"age"])  ## work on multiple cells

print(df.iloc[:2,[1,0]])
# Out:
# c    21
# d    20
# e    23
# f    24
# Name: age, dtype: int64
#    age     name
# a   23  susovan
# b   23    pupai

# %%
df
# Out:
#       name  age     city
# a  susovan   23    Delhi
# b    pupai   23   Mumbai
# c    sovan   21   Howrah
# d     Mimi   20  kolkata
# e   Taniya   23      Goa
# f      Ram   24   Huggly

# %%
print(df.iloc[0])
print(df.iloc[3,2])

print(df.iloc[1:3,2])  ### work on multiple cells
# Out:
# name    susovan
# age          23
# city      Delhi
# Name: a, dtype: object
# kolkata
# b    Mumbai
# c    Howrah
# Name: city, dtype: object

# %% [markdown]
# ### df.at[]: Access by Labels
# Use it when you know the row label and column name.
# ### df.iat[]: Access by Integer Position
# Use it when you know the row number and column number.

# %%
df.at['c',"age"]  ## fast data access
# Out:
# np.int64(21)

# %% [markdown]
# ### axis=0 👉 operate along rows (DOWN the rows, moving vertically)
#
# ### axis=1 👉 operate along columns (ACROSS the columns, moving horizontally)

# %%
 ## fast data access
df.iat[3,0]
# Out:
# 'Mimi'

# %% [markdown]
# ### df.drop() is used to delete rows or columns from a DataFrame.
# ✅ It returns a new DataFrame by default (it does NOT change the original DataFrame unless you set inplace=True).
#
# labels  ->	Row or column names (or indexes) to drop
#
# axis    ->	0 = rows (default), 1 = columns
#
# inplace -> False = return new DataFrame (default)
#         -> True = modify original DataFrame

# %%
df["salary"]=[2000,3000,8000,9000,4000,7000]   ## addd coloumn
df
# Out:
#       name  age     city  salary
# a  susovan   23    Delhi    2000
# b    pupai   23   Mumbai    3000
# c    sovan   21   Howrah    8000
# d     Mimi   20  kolkata    9000
# e   Taniya   23      Goa    4000
# f      Ram   24   Huggly    7000

# %%
new_df=df.drop("salary",axis=1)  ## not permently delete. return new datafame
new_df
# Out:
#       name  age     city
# a  susovan   23    Delhi
# b    pupai   23   Mumbai
# c    sovan   21   Howrah
# d     Mimi   20  kolkata
# e   Taniya   23      Goa
# f      Ram   24   Huggly

# %%
new_df
# Out:
#       name  age     city
# a  susovan   23    Delhi
# b    pupai   23   Mumbai
# c    sovan   21   Howrah
# d     Mimi   20  kolkata
# e   Taniya   23      Goa
# f      Ram   24   Huggly

# %%
df
# Out:
#       name  age     city  salary
# a  susovan   23    Delhi    2000
# b    pupai   23   Mumbai    3000
# c    sovan   21   Howrah    8000
# d     Mimi   20  kolkata    9000
# e   Taniya   23      Goa    4000
# f      Ram   24   Huggly    7000

# %%
df.drop("salary",axis=1,inplace=True)  # permently delet from current dataframe
df
# Out:
#       name  age     city
# a  susovan   23    Delhi
# b    pupai   23   Mumbai
# c    sovan   21   Howrah
# d     Mimi   20  kolkata
# e   Taniya   23      Goa
# f      Ram   24   Huggly

# %%
## add 
df["age"]=df["age"]+1
df
# Out:
#       name  age     city
# a  susovan   24    Delhi
# b    pupai   24   Mumbai
# c    sovan   22   Howrah
# d     Mimi   21  kolkata
# e   Taniya   24      Goa
# f      Ram   25   Huggly

# %%
df.drop('c') ## if want to delete permently do -> inplace=True
# Out:
#       name  age     city
# a  susovan   24    Delhi
# b    pupai   24   Mumbai
# d     Mimi   21  kolkata
# e   Taniya   24      Goa
# f      Ram   25   Huggly

# %%
### read csv file

df=pd.read_csv("sales_data.csv")

# %%
df.head(5)
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
df.tail(5)
# Out:
#      Transaction ID        Date Product Category  \
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
# 236                        Nike Air Force 1 Sneakers           3       90.00
# 237           The Handmaid's Tale by Margaret Atwood           3       10.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
# 239                       Yeti Rambler 20 oz Tumbler           2       29.99
#
#      Total Revenue         Region Payment Method
# 235         159.99         Europe         PayPal
# 236         270.00           Asia     Debit Card
# 237          32.97  North America    Credit Card
# 238          55.00         Europe         PayPal
# 239          59.98           Asia    Credit Card

# %%
print("data types : \n\n",df.dtypes)
# Out:
# data types :
#
#  Transaction ID        int64
# Date                 object
# Product Category     object
# Product Name         object
# Units Sold            int64
# Unit Price          float64
# Total Revenue       float64
# Region               object
# Payment Method       object
# dtype: object

# %%
print("statistical Summary: \n\n",df.describe())
# Out:
# statistical Summary:
#
#         Transaction ID  Units Sold   Unit Price  Total Revenue
# count       240.00000  240.000000   240.000000     240.000000
# mean      10120.50000    2.158333   236.395583     335.699375
# std          69.42622    1.322454   429.446695     485.804469
# min       10001.00000    1.000000     6.500000       6.500000
# 25%       10060.75000    1.000000    29.500000      62.965000
# 50%       10120.50000    2.000000    89.990000     179.970000
# 75%       10180.25000    3.000000   249.990000     399.225000
# max       10240.00000   10.000000  3899.990000    3899.990000

# %%
import pandas as pd
import numpy as np

marks_series=pd.Series([89,78,68,80,97],index=["Math","science","English","OPPs","Data science"],name="Susovan ka marks sheet")
marks_series
# Out:
# Math            89
# science         78
# English         68
# OPPs            80
# Data science    97
# Name: Susovan ka marks sheet, dtype: int64

# %%
print(marks_series.index,marks_series.dtype,marks_series.values,marks_series.is_unique)
# Out:
# Index(['Math', 'science', 'English', 'OPPs', 'Data science'], dtype='object') int64 [89 78 68 80 97] True

# %%
pd.read_csv("subs.csv")  ### default read as data fream
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
subs=pd.read_csv("subs.csv")['Subscribers gained']   ## series

# %%
vk=pd.read_csv('kohli_ipl.csv',index_col='match_no')['runs']
vk.head(6)
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# 6     9
# Name: runs, dtype: int64

# %%
bollywood=pd.read_csv("bollywood.csv",index_col='movie')['lead']
bollywood.head(5)
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
# Name: lead, dtype: object

# %%
bollywood.sample(3) ## randomly
# Out:
# movie
# Murder 2                 Emraan Hashmi
# Titoo MBA               Nishant Dahiya
# Anna (2016 film)    Shashank Udapurkar
# Name: lead, dtype: object

# %%
bollywood.value_counts().head(4)
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Name: count, dtype: int64

# %%
vk.sort_values(ascending=False).head(1).values[0]
# Out:
# np.int64(113)

# %%
bollywood.sort_index(inplace=True)
bollywood.head()
# Out:
# movie
# 1920 (film)               Rajniesh Duggall
# 1920: London                 Sharman Joshi
# 1920: The Evil Returns         Vicky Ahuja
# 1971 (2007 film)            Manoj Bajpayee
# 2 States (2014 film)          Arjun Kapoor
# Name: lead, dtype: object

# %%
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %%
vk.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
bollywood.describe()
# Out:
# count             1500
# unique             566
# top       Akshay Kumar
# freq                48
# Name: lead, dtype: object

# %%
bollywood[0]
# Out:
# C:\Users\susov\AppData\Local\Temp\ipykernel_8296\234213619.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   bollywood[0]
# 'Rajniesh Duggall'

# %%
bollywood["Titoo MBA"]
# Out:
# 'Nishant Dahiya'

# %%
vk[5:16]
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# Name: runs, dtype: int64

# %%
vk[::2]
# Out:
# match_no
# 1       1
# 3      13
# 5       1
# 7      34
# 9      21
#        ..
# 207     0
# 209    58
# 211     0
# 213    73
# 215     7
# Name: runs, Length: 108, dtype: int64

# %%
vk[[1,6,2,9]]
# Out:
# match_no
# 1     1
# 6     9
# 2    23
# 9    21
# Name: runs, dtype: int64

# %%
marks_series[1]=100
marks_series["OS"]=99
marks_series
# Out:
# C:\Users\susov\AppData\Local\Temp\ipykernel_8296\1319978038.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1]=100
# Math             89
# science         100
# English          68
# OPPs             80
# Data science     97
# OS               99
# Name: Susovan ka marks sheet, dtype: int64

# %%
print(dir(subs))
print(sorted(subs))
print(min(subs),max(subs))
len(subs)
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__bool__', '__class__', '__column_consortium_standard__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__weakref__', '__xor__', '_accessors', '_accum_func', '_agg_examples_doc', '_agg_see_also_doc', '_align_for_op', '_align_frame', '_align_series', '_append', '_arith_method', '_as_manager', '_attrs', '_binop', '_cacher', '_can_hold_na', '_check_inplace_and_allows_duplicate_labels', '_check_is_chained_assignment_possible', '_check_label_or_level_ambiguity', '_check_setitem_copy', '_clear_item_cache', '_clip_with_one_bound', '_clip_with_scalar', '_cmp_method', '_consolidate', '_consolidate_inplace', '_construct_axes_dict', '_construct_result', '_constructor', '_constructor_expanddim', '_constructor_expanddim_from_mgr', '_constructor_from_mgr', '_data', '_deprecate_downcast', '_dir_additions', '_dir_deletions', '_drop_axis', '_drop_labels_or_levels', '_duplicated', '_find_valid_index', '_flags', '_flex_method', '_from_mgr', '_get_axis', '_get_axis_name', '_get_axis_number', '_get_axis_resolvers', '_get_block_manager_axis', '_get_bool_data', '_get_cacher', '_get_cleaned_column_resolvers', '_get_index_resolvers', '_get_label_or_level_values', '_get_numeric_data', '_get_rows_with_mask', '_get_value', '_get_values_tuple', '_get_with', '_getitem_slice', '_gotitem', '_hidden_attrs', '_indexed_same', '_info_axis', '_info_axis_name', '_info_axis_number', '_init_dict', '_init_mgr', '_inplace_method', '_internal_names', '_internal_names_set', '_is_cached', '_is_copy', '_is_label_or_level_reference', '_is_label_reference', '_is_level_reference', '_is_mixed_type', '_is_view', '_is_view_after_cow_rules', '_item_cache', '_ixs', '_logical_func', '_logical_method', '_map_values', '_maybe_update_cacher', '_memory_usage', '_metadata', '_mgr', '_min_count_stat_function', '_name', '_needs_reindex_multi', '_pad_or_backfill', '_protect_consolidate', '_reduce', '_references', '_reindex_axes', '_reindex_indexer', '_reindex_multi', '_reindex_with_indexers', '_rename', '_replace_single', '_repr_data_resource_', '_repr_latex_', '_reset_cache', '_reset_cacher', '_set_as_cached', '_set_axis', '_set_axis_name', '_set_axis_nocheck', '_set_is_copy', '_set_labels', '_set_name', '_set_value', '_set_values', '_set_with', '_set_with_engine', '_shift_with_freq', '_slice', '_stat_function', '_stat_function_ddof', '_take_with_is_copy', '_to_latex_via_styler', '_typ', '_update_inplace', '_validate_dtype', '_values', '_where', 'abs', 'add', 'add_prefix', 'add_suffix', 'agg', 'aggregate', 'align', 'all', 'any', 'apply', 'argmax', 'argmin', 'argsort', 'array', 'asfreq', 'asof', 'astype', 'at', 'at_time', 'attrs', 'autocorr', 'axes', 'backfill', 'between', 'between_time', 'bfill', 'bool', 'case_when', 'clip', 'combine', 'combine_first', 'compare', 'convert_dtypes', 'copy', 'corr', 'count', 'cov', 'cummax', 'cummin', 'cumprod', 'cumsum', 'describe', 'diff ...
# [33, 33, 35, 37, 39, 40, 40, 40, 40, 42, 42, 43, 44, 44, 44, 45, 46, 46, 48, 49, 49, 49, 49, 50, 50, 50, 51, 54, 56, 56, 56, 56, 57, 61, 62, 64, 65, 65, 66, 66, 66, 66, 67, 68, 70, 70, 70, 71, 71, 72, 72, 72, 72, 72, 73, 74, 74, 75, 76, 76, 76, 76, 77, 77, 78, 78, 78, 79, 79, 80, 80, 80, 81, 81, 82, 82, 83, 83, 83, 84, 84, 84, 85, 86, 86, 86, 87, 87, 87, 87, 88, 88, 88, 88, 88, 89, 89, 89, 90, 90, 90, 90, 91, 92, 92, 92, 93, 93, 93, 93, 95, 95, 96, 96, 96, 96, 97, 97, 98, 98, 99, 99, 100, 100, 100, 101, 101, 101, 102, 102, 103, 103, 104, 104, 104, 105, 105, 105, 105, 105, 105, 105, 105, 105, 108, 108, 108, 108, 108, 108, 109, 109, 110, 110, 110, 111, 111, 112, 113, 113, 113, 114, 114, 114, 114, 115, 115, 115, 115, 117, 117, 117, 118, 118, 119, 119, 119, 119, 120, 122, 123, 123, 123, 123, 123, 124, 125, 126, 127, 128, 128, 129, 130, 131, 131, 132, 132, 134, 134, 134, 135, 135, 136, 136, 136, 137, 138, 138, 138, 139, 140, 144, 145, 146, 146, 146, 146, 147, 149, 150, 150, 150, 150, 151, 152, 152, 152, 153, 153, 153, 154, 154, 154, 155, 155, 156, 156, 156, 156, 157, 157, 157, 157, 158, 158, 159, 159, 160, 160, 160, 160, 162, 164, 166, 167, 167, 168, 170, 170, 170, 170, 171, 172, 172, 173, 173, 173, 174, 174, 175, 175, 176, 176, 177, 178, 179, 179, 180, 180, 180, 182, 183, 183, 183, 184, 184, 184, 185, 185, 185, 185, 186, 186, 186, 188, 189, 190, 190, 192, 192, 192, 196, 196, 196, 197, 197, 202, 202, 202, 203, 204, 206, 207, 209, 210, 210, 211, 212, 213, 214, 216, 219, 220, 221, 221, 222, 222, 224, 225, 225, 226, 227, 228, 229, 230, 231, 233, 236, 236, 237, 241, 243, 244, 245, 247, 249, 254, 254, 258, 259, 259, 261, 261, 265, 267, 268, 269, 276, 276, 290, 295, 301, 306, 312, 396]
# 33 396
# 365

# %%
lst=list(marks_series)
lst
# Out:
# [89, 100, 68, 80, 97, 99]

# %%
'2 States (2014 film)' in bollywood.index
# Out:
# True

# %%
'Salman Khan' in bollywood.values
# Out:
# True

# %%
for i in bollywood:
    print(i)
# Out:
# Rajniesh Duggall
# Sharman Joshi
# Vicky Ahuja
# Manoj Bajpayee
# Arjun Kapoor
# Barun Sobti
# Salil Acharya
# Naseeruddin Shah
# Aamir Khan
# Aisha Ahmed
# Soha Ali Khan
# Akshaye Khanna
# Neil Nitin Mukesh
# Sara Arjun
# Nargis Fakhri
# Mouli Ganguly
# Vipin Sharma
# Yeh Saali Aashiqui
# Youngistaan
# Yun Hota Toh Kya Hota
# Yuva
# Yuvvraaj
# Zamaanat
# Zameen (2003 film)
# Zameer: The Fire Within
# Zed Plus
# Zeher
# Zero (2018 film)
# Zid (2014 film)
# Zila Ghaziabad
# Zinda (film)
# Zindaggi Rocks
# Zindagi 50-50
# Zindagi Na Milegi Dobara
# Zindagi Tere Naam
# Zokkomon
# Zor Lagaa Ke...Haiya!

# %%
100-marks_series   ### broadcusting
# Out:
# Math            11
# science          0
# English         32
# OPPs            20
# Data science     3
# OS               1
# Name: Susovan ka marks sheet, dtype: int64

# %%
vk[vk>50].size  ## boolinan indexing
# Out:
# 48

# %%
vk[vk==0].size
# Out:
# 9

# %%
subs[subs>200].size
# Out:
# 59

# %%
num_movies=bollywood.value_counts()
num_movies[num_movies>20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
import sys
print(sys.getsizeof(vk))
vk=vk.astype('int16')   ## type change
print(sys.getsizeof(vk))
# Out:
# 11768
# 10478

# %%
subs.clip(100,200)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# drop Duplicates
data=pd.Series(np.random.randint(1,10,30))
data.drop_duplicates(keep="last")
# Out:
# 14    6
# 20    9
# 21    3
# 24    1
# 25    4
# 26    5
# 27    8
# 28    2
# 29    7
# dtype: int32

# %%
bollywood.duplicated().sum()
# Out:
# np.int64(934)

# %%
temp=pd.Series([1,2,4,np.nan,9,7,np.nan,2,np.nan,8,34,np.nan,90,123])
print(temp.count(),temp.size)
print(temp.isnull().sum())
temp.dropna()
# Out:
# 10 14
# 4
# 0       1.0
# 1       2.0
# 2       4.0
# 4       9.0
# 5       7.0
# 7       2.0
# 9       8.0
# 10     34.0
# 12     90.0
# 13    123.0
# dtype: float64

# %%
temp.fillna(temp.mean())
# Out:
# 0       1.0
# 1       2.0
# 2       4.0
# 3      28.0
# 4       9.0
# 5       7.0
# 6      28.0
# 7       2.0
# 8      28.0
# 9       8.0
# 10     34.0
# 11     28.0
# 12     90.0
# 13    123.0
# dtype: float64

# %%
vk[(vk==49) | (vk==99)]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int16

# %%
vk.isin([99,49,0])
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211     True
# 212    False
# 213    False
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %%
vk[vk.isin([49,99,0])]
# Out:
# match_no
# 8       0
# 82     99
# 86     49
# 87      0
# 91      0
# 93      0
# 130     0
# 135     0
# 206     0
# 207     0
# 211     0
# Name: runs, dtype: int16

# %%
bollywood.apply(lambda x:x.split()[0].upper()).head()
# Out:
# movie
# 1920 (film)               RAJNIESH
# 1920: London               SHARMAN
# 1920: The Evil Returns       VICKY
# 1971 (2007 film)             MANOJ
# 2 States (2014 film)         ARJUN
# Name: lead, dtype: object

# %%
subs.apply(lambda x: "good day" if x>subs.mean() else "bad day")
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
subs.apply(lambda x: "good day" if x>subs.mean() else "bad day").value_counts()
# Out:
# Subscribers gained
# bad day     202
# good day    163
# Name: count, dtype: int64

# %%
### copy
new_subs=subs.head(6)
new_subs
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# 5    46
# Name: Subscribers gained, dtype: int64

# %%
# change some value
new_subs[1]=111
new_subs[2]=222
print(new_subs)
# Out:
# 0     48
# 1    111
# 2    222
# 3     43
# 4     44
# 5     46
# Name: Subscribers gained, dtype: int64

# %%
subs ## here also autometicaly change
# Out:
# 0       48
# 1      111
# 2      222
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
## use copy
new_subs=subs.head(6).copy()
new_subs[1]=99
new_subs[2]=333
new_subs[3]=222
new_subs
# Out:
# 0     48
# 1     99
# 2    333
# 3    222
# 4     44
# 5     46
# Name: Subscribers gained, dtype: int64

# %%
subs ### no change here
# Out:
# 0       48
# 1      111
# 2      222
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
bollywood.drop_duplicates()
# Out:
# movie
# 1920 (film)               Rajniesh Duggall
# 1920: London                 Sharman Joshi
# 1920: The Evil Returns         Vicky Ahuja
# 1971 (2007 film)            Manoj Bajpayee
# 2 States (2014 film)          Arjun Kapoor
#                                 ...
# Yeh Saali Aashiqui            Vardhan Puri
# Zed Plus                     Vinod Acharya
# Zid (2014 film)             Mannara Chopra
# Zindagi 50-50                  Veena Malik
# Zor Lagaa Ke...Haiya!        Meghan Jadhav
# Name: lead, Length: 566, dtype: object

# %%
vk[vk.between(40,79)].plot()
# Out:
# <Axes: xlabel='match_no'>

# %%
subs.plot()
# Out:
# <Axes: >

# %%
bollywood.value_counts().head(20).plot(kind="bar")
# Out:
# <Axes: xlabel='lead'>

# %%
bollywood.value_counts().head(20).plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# | **Method**                       | **What It Does**                                          |
# | -------------------------------- | --------------------------------------------------------- |
# | `pd.DataFrame(data)`             | Create a DataFrame from data (list, dict, array, etc.).   |
# | `df.set_index('column')`         | Set a column as the row index.                            |
# | `df.loc[row, col]`               | Access rows and columns by labels.                        |
# | `df.iloc[row, col]`              | Access rows and columns by index positions.               |
# | `df['new_column'] = ...`         | Add a new column to the DataFrame.                        |
# | `df.sum(axis=0)`                 | Compute column-wise sum (default).                        |
# | `df.sum(axis=1)`                 | Compute row-wise sum.                                     |
# | `df.fillna(value)`               | Replace all NaN (missing values) with a specified value.  |
# | `df.fillna(df.mean())`           | Replace NaN with the column mean.                         |
# | `df.dropna()`                    | Drop rows with any NaN values.                            |
# | `df.groupby('col')`              | Group data by unique values in a column.                  |
# | `df.groupby('col')['val'].sum()` | Group by column and compute sum of another column.        |
# | `df.groupby(['A', 'B'])`         | Perform grouping on multiple columns (multi-level group). |
# | `pd.merge(df1, df2, on='col')`   | Merge two DataFrames using a common column.               |
# | `pd.concat([df1, df2], axis=0)`  | Concatenate DataFrames vertically (row-wise).             |
# | `pd.concat([df1, df2], axis=1)`  | Concatenate DataFrames horizontally (column-wise).        |
# | `pd.date_range(start, end)`      | Create a date range (useful for datetime index).          |
# | `df.resample('M').mean()`        | Resample data (e.g., monthly) and compute mean.           |
# | `df.rolling(window=7).mean()`    | Compute a rolling (moving) average over a window size.    |
# | `pd.MultiIndex.from_tuples()`    | Create a multi-level (hierarchical) index.                |
# | `df.loc[('A', 'X')]`             | Access data from a MultiIndex DataFrame.                  |
# | `df.sum(level='Category')`       | Sum over one level in a MultiIndex DataFrame.             |
# | `pd.pivot_table()`               | Create pivot tables for summarizing data.                 |
# | `df.apply(func)`                 | Apply a function row-wise or column-wise.                 |
# | `df.applymap(func)`              | Apply a function element-wise on all DataFrame values.    |
# | `series.str.upper()`             | Convert all strings in a Series to uppercase.             |
# | `series.str[:3]`                 | Slice the first 3 characters of each string in a Series.  |

# %% [markdown]
# ### ✅ Key Pandas Concepts from Your Assignments
#
# ### 📄 Assignment 1: DataFrame Creation and Indexing
# pd.DataFrame(data) → Creates a DataFrame.
#
# df.set_index('column_name') → Sets a column as index.
#
# df.loc[row_label, column_label] → Access data by row and column labels.
#
# ### 📄 Assignment 2: DataFrame Operations
# df['new_column'] = df['A'] * df['B'] → Add new column from operations.
#
# df.sum(axis=0) → Column-wise sum.
#
# df.sum(axis=1) → Row-wise sum.
#
# ### 🧹 Assignment 3: Data Cleaning
# df.fillna(value) → Fill NaN with specified value.
#
# df.fillna(df.mean()) → Fill NaN with column mean.
#
# df.dropna() → Drops rows with any NaN values.
#
# ### 📊 Assignment 4: Data Aggregation
# df.groupby('Category')['Value'].sum() → Group by and aggregate.
#
# df.groupby('Category')['Value'].mean() → Mean per group.
#
# df.groupby(['Category', 'SubCategory']) → Multi-level grouping.
#
# ### 🔗 Assignment 5: Merging DataFrames
# pd.merge(df1, df2, on='common_column') → Merge on common column.
#
# pd.concat([df1, df2], axis=0) → Concatenate along rows.
#
# pd.concat([df1, df2], axis=1) → Concatenate along columns.
#
# ### 🕑 Assignment 6: Time Series Analysis
# pd.date_range(start, end) → Create date index.
#
# df.resample('M').mean() → Resample to monthly mean.
#
# df.rolling(window=7).mean() → Rolling window of 7 days.
#
# ### 🔗 Assignment 7: MultiIndex DataFrame
# pd.MultiIndex.from_tuples() → Create multi-level index.
#
# df.loc[('A', 'X')] → Access MultiIndex data.
#
# df.sum(level='Category') → Sum over MultiIndex level.
#
# ### 📌 Assignment 8: Pivot Tables
# pd.pivot_table(df, values='Value', index='Date', columns='Category', aggfunc='sum') → Create pivot tables.
#
# ⚙️ Assignment 9: Applying Functions
# df.apply(func) → Apply function to DataFrame.
#
# df.applymap(func) → Apply function element-wise.
#
# df['new'] = df.apply(lambda row: row.sum(), axis=1) → Row-wise operation.
#
# ### ✏️ Assignment 10: Working with Text Data
# series.str.upper() → Convert text to uppercase.
#
# series.str[:3] → Slice first 3 characters of each stri
