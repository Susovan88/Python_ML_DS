# %% [markdown]
# ### Matplotlib is a Python library used to create charts and graphs.
#
# It helps you visualize data in many ways:
# 📈 Line Charts
# 📊 Bar Charts
# 📦 Histograms
# 🥧 Pie Charts
# …and more.
#
# Think of it like the paintbrush for your data 🎨

# %%
import matplotlib.pyplot as plt

x=[23,45,60,76,90]
y=[10,34,26,90,24]

plt.plot(x,y)
plt.xlabel("X Axis")
plt.ylabel("Y Aixs")
plt.title("Basic line Plot")
plt.show()

# %%
plt.plot(x,y,color="green",linestyle="--",marker='o',linewidth=1,markersize=4)
# plt.grid(True)
plt.show()

# %%
x = [1, 12, 3, 4, 15, 6, 7]
y1 = [2, 14, 6, 8, 19, 12, 14]
y2 = [11, 3, 5, 17, 9, 1, 13]
plt.figure(figsize=(9,5))

plt.subplot(2,2,1)
plt.plot(x,y1,color="Blue",linestyle="--",marker='o',linewidth=1,markersize=4)
plt.title("plot 1")

plt.subplot(2,2,2)
plt.plot(x,y2,color="Green",linestyle="--",marker='o',linewidth=1,markersize=4)
plt.title("plot 2")

plt.subplot(2,2,3)
plt.plot(y1,y2,color="Green",linestyle="--",marker='o',linewidth=1,markersize=4)
plt.title("plot 3")

z=[i*2 for i in x]
print(z)

plt.subplot(2,2,4)
plt.plot(x,z,color="Red",linestyle="--",marker='o',linewidth=1,markersize=4)
plt.title("plot 4")
# Out:
# [2, 24, 6, 8, 30, 12, 14]
# Text(0.5, 1.0, 'plot 4')

# %%
### Bar Plor
categories = ["A", "B", "C", "D", "E", "F", "G", "H"]
values = [10, 15, 7, 20, 5, 12, 18, 9]

plt.bar(categories,values,color="Blue")
plt.ylabel("values")
plt.xlabel("categories")
plt.title("Basic Bar Plot")
# Out:
# Text(0.5, 1.0, 'Basic Bar Plot')

# %% [markdown]
# ### A Histogram is used to show the distribution of data (how data is spread out).
#
# It divides your data into bins (intervals) and then counts how many data points fall into each bin.
#
# Think of it like:
#
# Grouping similar values together
#
# Showing how many times values appear in each group
#
# ###  A bin is like a container (or range) that groups your data.
#
# When you create a histogram:
#
# The data gets split into intervals (bins).
#
# Each bin counts how many data points fall inside it.
#
# Then it draws a bar for each bin 📊

# %%
## histograms 
data=[10, 20, 22, 35, 40, 45, 55, 60, 75, 80, 85, 90, 95]
plt.hist(data,bins=5,color="gray",edgecolor="black")
# Out:
# (array([3., 2., 3., 1., 4.]),
#  array([10., 27., 44., 61., 78., 95.]),
#  <BarContainer object of 5 artists>)

# %%
### create a scatter Plot
x = [1, 12, 3, 12, 3, 4, 15, 6, 7, 4, 15, 6, 7]
y1 = [2, 14, 6, 8, 14, 6, 8, 19, 12, 14, 19, 12, 14]

plt.scatter(x,y1,color="red",marker="*")

# %%
### pipe chart
labels = ["A", "B", "C", "D", "E", "F", "G", "H"]
values = [10, 23, 13, 18, 5, 7, 16, 8]
colors = [
    "gold",         # 🟡 gold
    "lightcoral",   # 🔴 soft coral
    "lightskyblue", # 🔵 light blue
    "palegreen",    # 🟢 soft green
    "plum",         # 🟣 light purple
    "salmon",       # 🟥 salmon pink
    "orange",       # 🟠 orange
    "violet"        # 🟪 violet
]
explode=(0,0.2,0,0,0,0,0,0)

plt.pie(values,colors=colors,labels=labels,explode=explode,shadow=True,)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f22f6d8da0>,
# ...
#  [Text(1.0461621649530053, 0.3399187029582827, 'A'),
#   Text(0.28358612075114825, 1.2686918113227164, 'B'),
#   Text(-0.869170552138986, 0.6741977093512039, 'C'),
#   Text(-1.0461620947148778, -0.33991891912892863, 'D'),
#   Text(-0.5599457519839817, -0.9468161145835519, 'E'),
#   Text(-0.17207745003216413, -1.0864572477508851, 'F'),
#   Text(0.5894092565901207, -0.9287608563273333, 'G'),
#   Text(1.0654413666270954, -0.2735593066956181, 'H')])

# %%
### 
import pandas as pd
sales_data_df=pd.read_csv("sales_data.csv")
sales_data_df.head(5)
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
sales_data_df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Product Category    0
# Product Name        0
# Units Sold          0
# Unit Price          0
# Total Revenue       0
# Region              0
# Payment Method      0
# dtype: int64

# %%
sales_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    240 non-null    int64
#  1   Date              240 non-null    object
#  2   Product Category  240 non-null    object
#  3   Product Name      240 non-null    object
#  4   Units Sold        240 non-null    int64
#  5   Unit Price        240 non-null    float64
#  6   Total Revenue     240 non-null    float64
#  7   Region            240 non-null    object
#  8   Payment Method    240 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 17.0+ KB

# %%
total_product_sales=sales_data_df.groupby("Product Name")["Total Revenue"].sum()
total_product_sales.plot(kind="pie",shadow=True)
# Out:
# <Axes: ylabel='Total Revenue'>

# %%
total_product_sales=sales_data_df.groupby("Product Category")["Total Revenue"].sum()
total_product_sales.plot(kind="bar",color="orange")
# Out:
# <Axes: xlabel='Product Category'>

# %% [markdown]
# ### What is .reset_index()?
# When you use .reset_index(), it resets the index of your DataFrame back to the default numbers 0,1,2,....

# %%
sales_on_date=sales_data_df.groupby("Date")["Total Revenue"].sum().reset_index()
plt.plot(sales_on_date["Date"],sales_on_date["Total Revenue"])
